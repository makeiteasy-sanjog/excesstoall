# %% [markdown]
# #  NAME  - SANJOG MOHANTY

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Student_score.csv")

# %%
df.head(4)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75

# %%
df.shape # no of row and no of no. columns
# Out:
# (25, 2)

# %%
df.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
plt.figure(figsize=(10, 3))
sns.set_style('whitegrid')
sns.scatterplot(x='Hours',y='Scores',data=df)
# Out:
# <AxesSubplot:xlabel='Hours', ylabel='Scores'>

# %%
plt.figure(figsize=(10, 3))
sns.lineplot(x='Hours',y='Scores',data=df)
# Out:
# <AxesSubplot:xlabel='Hours', ylabel='Scores'>

# %%
sns.heatmap(df.corr(),annot=True,cmap='gist_yarg_r')
# Out:
# <AxesSubplot:>

# %%
df['Hours'].max()

df['Hours'].mean()
# Out:
# 5.012

# %%
df.sort_values(['Hours','Scores'],ascending=['True','True']).head(6)
# Out:
#     Hours  Scores
# 14    1.1      17
# 5     1.5      20
# 17    1.9      24
# 0     2.5      21
# 16    2.5      30
# 9     2.7      25

# %%
df.sort_values(['Hours','Scores'],ascending=['True','True']).max()
df.sort_values(['Hours','Scores'],ascending=['True','True']).min()
# Out:
# Hours      1.1
# Scores    17.0
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,0].values # independent variable # hours column
y=df.iloc[:,1].values # dependent variable  # score column
x=np.array(x).reshape(-1,1)
y=np.array(y).reshape(-1,1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9454906892105355

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([[16.88414476],
#        [33.73226078],
#        [75.357018  ],
#        [26.79480124],
#        [60.49103328]])

# %%
x_test
# Out:
# array([[1.5],
#        [3.2],
#        [7.4],
#        [2.5],
#        [5.9]])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9454906892105355

# %%
from sklearn.metrics import r2_score_score

# %% [markdown]
# # what will be prediction score if a student studies for 9.25 hrs/day

# %%
test=np.array([9.25]).reshape(-1,1)

# %%
model.predict(test)
# Out:
# array([[93.69173249]])
